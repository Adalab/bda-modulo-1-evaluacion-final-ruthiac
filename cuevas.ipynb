# %% [markdown]
# TIENDA DE ALIMENTOS LULU

# %%
class tienda :
    def __init__(self, articulo, precio, cantidad):
        self.articulo = articulo    
        self.precio = precio
        self.cantidad = cantidad


articulo = {"alimento para perro adulto raza pequeña de 1kg", "alimento para perro adulto raza mediana de 1kg", "alimento para perro adulto raza grande  de1kg",
"alimento para perro joven raza pequeña de 1kg", "alimento para perro joven raza mediana de 1kg ", "alimento para perro joven raza grande de 1kg",
"alimento para perro cachorro raza pequeña de 1 kg", "alimento para perro cachorro raza mediana de 1 kg", "alimento para perro cachorro raza grande de 1kg"}
#precio = [ 3, 4, 4, 3, 4, 4, 3, 3, 4]
# ver donde esta el errror cantidad = {50, 60, 70, 55, 65, 75, 45,  55,  65 }  
perro_adulto_peq = tienda ("alimento para perro adulto raza pequeña de 1kg", 3, 50)
perro_adulto_mediana = tienda("alimento_para_perro_adulto_raza_mediana_de_1kg", 4, 60)
perro_adulto_grande = tienda("alimento_para_perro_adulto_raza_grande_de_1kg", 4, 70)
perro_joven_peq = tienda("alimento_para_perro_joven_raza_pequeña_de_1kg", 3, 55)
perro_joven_mediana = tienda("alimento_para_perro_joven_raza_mediana_de_1kg", 4, 65)
perro_joven_grande = tienda("alimento_para_perro_joven_raza_grande_de_1kg", 4, 75)
perro_cachorro_peq = tienda("alimento_para_perro_cachorro_raza_pequeña_de_1kg", 3, 45)
perro_cachorro_mediana = tienda("alimento_para_perro_cachorro_raza_mediana_de_1kg", 3, 55)
perro_cachorro_grande = tienda("alimento_para_perro_cachorro_raza_grande_de_1kg", 4, 65)  

lista_productos= [perro_adulto_peq, perro_adulto_mediana, perro_adulto_grande,
 perro_joven_peq,perro_joven_mediana, perro_joven_grande,
 perro_cachorro_peq, perro_cachorro_mediana, perro_cachorro_grande]
print(lista_productos)

for productos in lista_productos:
    print ("Alimentos: ", productos.articulo)
    print ("Cantidad: ", productos.cantidad)
    print ("Precio total de compra:  $", productos.precio)



class clientes:
    def __init__(self, nombre_apellidos, email):
        self.nom_apell = nombre_apellidos
        self.correo = email
        self.compras =[]
    def compras_realizadas( self, productos):
        self.compras.append(productos)
    def productos_comprados (self):
        for productos in self.compras:
             print ("Alimentos: ", productos.articulo)
             print ("Cantidad: ", productos.cantidad)
             print(f"Precio total de {productos.articulo}:  ${productos.precio}")
cliente1= clientes ("marcos billordo", "bmarcos@gmail.com")
articulo1 = input("Hola que alimento estas buscando")
print ("Hola que alimento estas buscando: ", articulo1 )
cantidad1= int(input("cuanta cantidad os quiere"))
print ("la cantidad essss  :" , cantidad1)
precio1=0
if ("adulto" in articulo1):
    precio1 = cantidad1 * lista_productos[0].precio
    print ("hola: ", precio1)

elif ("pequeña" in articulo1):
    precio1 = cantidad1 * lista_productos[2].precio

elif ("mediana" in articulo1):
    precio1 = cantidad1 * lista_productos[1].precio

else:
    ("Lamentamos no tener tu producto solicitado")








cliente1.compras_realizadas(tienda(articulo1, precio1, cantidad1))
cliente1.productos_comprados()
# Out:
# [<__main__.tienda object at 0x0000015863F417F0>, <__main__.tienda object at 0x00000158639E7C50>, <__main__.tienda object at 0x00000158632BDD10>, <__main__.tienda object at 0x0000015862BB7CE0>, <__main__.tienda object at 0x0000015862BB7BB0>, <__main__.tienda object at 0x0000015864083650>, <__main__.tienda object at 0x0000015863E3D370>, <__main__.tienda object at 0x0000015863E3C490>, <__main__.tienda object at 0x0000015863EAAF50>]
# Alimentos:  alimento para perro adulto raza pequeña de 1kg
# Cantidad:  50
# Precio total de compra:  $ 3
# Alimentos:  alimento_para_perro_adulto_raza_mediana_de_1kg
# Cantidad:  60
# Precio total de compra:  $ 4
# Alimentos:  alimento_para_perro_adulto_raza_grande_de_1kg
# Cantidad:  70
# Precio total de compra:  $ 4
# Alimentos:  alimento_para_perro_joven_raza_pequeña_de_1kg
# Cantidad:  55
# Precio total de compra:  $ 3
# Alimentos:  alimento_para_perro_joven_raza_mediana_de_1kg
# Cantidad:  65
# Precio total de compra:  $ 4
# ...
