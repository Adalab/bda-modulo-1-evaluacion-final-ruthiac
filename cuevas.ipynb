# %% [markdown]
# # TIENDA DE ALIMENTOS LULU

# %% [markdown]
# # 📌 1)INVENTARIO DE ALIMENTOS, PRECIOS Y CANTIDAD
# **Lista de diccionario**

# %%
alimentos_perros =[ 
                    {"nombre" : "alimento para perro adulto raza pequeña", "precio" : 2,"cantidad": 50}, 
                    { "nombre" : "alimento para perro joven raza pequeña de 1kg", "precio" : 3,"cantidad": 55},
                    {"nombre" : "alimento para perro cachorro raza pequeña de 1kg", "precio": 4,"cantidad": 45}
                           
                       
]
    
for arti in alimentos_perros:
    print(f"Alimento: {arti[nombre]}")
    print(f"  Precio: {arti[precio]} €")
    print(f"  Cantidad disponible: {arti[cantidad]}")
# Out:
# Alimento: alimento para perro adulto raza pequeña
#   Precio: 2 €
#   Cantidad disponible: 50
# Alimento: alimento para perro joven raza pequeña de 1kg
#   Precio: 3 €
#   Cantidad disponible: 55
# Alimento: alimento para perro cachorro raza pequeña de 1kg
#   Precio: 4 €
#   Cantidad disponible: 45

# %% [markdown]
# # 📌 2) CLIENTES
# **DICCIONARIO**

# %%
clientes = {
    "cliente1": {"nombre": "Juan Perez", "email" : "juan1@gmai.com", "compra": []},
    "cliente2": {"nombre": "Ana Gomez", "email" : "ana2@gmail.com", "compra": []},
    "cliente3": {"nombre": "Luis Martinez", "email" : "luis3@gmail.com", "compra": []}}
#defino cliente_info a las palabras clave del diccionario

for cliente_id, cliente_info in clientes.items():
    print(f"ID Cliente: {cliente_id}")
    print(f"  Nombre: {cliente_info['nombre']}")
    print(f"  Email: {cliente_info['email']}")
    print(f"  Compras: {cliente_info['compra']}")
# Out:
# ID Cliente: cliente1
#   Nombre: Juan Perez
#   Email: juan1@gmai.com
#   Compras: []
# ID Cliente: cliente2
#   Nombre: Ana Gomez
#   Email: ana2@gmail.com
#   Compras: []
# ID Cliente: cliente3
#   Nombre: Luis Martinez
#   Email: luis3@gmail.com
#   Compras: []

# %% [markdown]
# # 📌 3) VENTAS TOTALES

# %%
# Simulacion de compras
ventas_totales = 0.0
clientes_totales = clientes.keys()
deseo_comprar = alimentos_perros[1] #accedo al producto que quiero comprar que se guarda en la variable deseo_comprar
 #agrego el producto al diccionario de compras del cliente1 usando append
for cliente in clientes_totales: 
    clientes[cliente]["compra"].append(deseo_comprar)
    print(f"Hola el Producto comprado: {['nombre']}, Precio: {producto['precio']} €, Cantidad: {producto['cantidad']}")



for cliente_info in clientes.values(): # recorro los valores del diccionario clientes
    for producto in cliente_info["compra"]: # recorro los productos en la lista de compras de cada cliente
        ventas_totales += producto["precio"] # sumo el precio de cada producto a las ventas totales
        
print(f"Ventas totales: {ventas_totales} €")
# Out:
# Hola el Producto comprado: alimento para perro adulto raza pequeña, Precio: 2 €, Cantidad: 50
# Hola el Producto comprado: alimento para perro adulto raza pequeña, Precio: 2 €, Cantidad: 50
# Hola el Producto comprado: alimento para perro adulto raza pequeña, Precio: 2 €, Cantidad: 50
# Hola el Producto comprado: alimento para perro adulto raza pequeña, Precio: 2 €, Cantidad: 50
# Hola el Producto comprado: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Hola el Producto comprado: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Hola el Producto comprado: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Hola el Producto comprado: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Hola el Producto comprado: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Hola el Producto comprado: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# ...

# %%
#segunda parte 

#seteo un valor de default por si el el empleado actualiza la cantidad del producto
def agregar_producto (nombre, cantidad, precio):
    # Recorro los productos en el diccionario alimentos_perros y verifico si el producto ya existe
    for alimentos_perro in alimentos_perros:
        if alimentos_perro['nombre'] == nombre:
            print(f"El articulo {nombre} ya existe. Se actualizará la cantidad.")
            alimentos_perro['cantidad'] += cantidad
            print(f"Nueva cantidad de {nombre}: {alimentos_perro['cantidad']}")
            #si exite el alimento de perro no se agrega el precio
            print(f"Precio de {nombre}: {alimentos_perro['precio']} €, no se modifica porque ya existe.")
            #se encontro el articulo por eso se procede con un return para cortar la ejecucion
            return
    #si no se encontro el articulo, lo agrego como nuevo
    alimentos_perros.append({'nombre': nombre, 'precio': precio, 'cantidad': cantidad})

def ver_inventario():
    print("Inventario actual:")
    for alimento in alimentos_perros:
        print(f"Articulo: {alimento['nombre']}, Precio: {alimento['precio']} €, Cantidad: {alimento['cantidad']}")
        
while True:
    articulo_seleccionado= input("Ingrese el nombre del articulo que desea agregar o actualizar: ")
    precio_nuevo_producto = float(input("Ingrese el precio del nuevo producto: "))  
    cantidad_nuevo_producto = int(input("Ingrese la cantidad del nuevo producto: "))      
    agregar_producto(articulo_seleccionado, cantidad_nuevo_producto, precio_nuevo_producto)
    ver_inventario()
    continuar = input("¿Desea agregar o actualizar otro producto? (si/no): ")
    if continuar.lower() != 's':
        break
  
def buscar_producto(nombre):
    for alimento in alimentos_perros:
        if alimento['nombre'].lower() == nombre.lower():
            print(f"Nombre: {alimento['nombre']}, Precio: {alimento['precio']} €, Cantidad: {alimento['cantidad']}")
            return   
    print(f"El producto '{nombre}' no se encontró en el inventario.")
    
buscar_producto("alimento para perro joven raza pequeña de 1kg")    
def actualizar_stock(nombre, nueva_cantidad):
    for alimento in alimentos_perros:
        if alimento['nombre'].lower() == nombre.lower():
            alimento['cantidad'] = alimento['cantidad'] + nueva_cantidad
            print(f"Stock actualizado para {nombre}. Nueva cantidad: {nueva_cantidad}")
            return
    print(f"El producto '{nombre}' no se encontró en el inventario.")

actualizar_stock("alimento para perro cachorro raza pequeña de 1kg", 60)

def eliminar_producto(nombre):    
    for alimento in alimentos_perros:
        if alimento['nombre'].lower() == nombre.lower():
            alimentos_perros.remove(alimento)
            print(f"El producto '{nombre}' ha sido eliminado del inventario.")
            return
    print(f"El producto '{nombre}' no se encontró en el inventario.")

eliminar_producto("alimento para perro adulto raza pequeña")

#aca me pide que devuelva el valor total del inventario no que imprima, quizas en el futuro lo use para otra cosa
def calcular_valor_inventario():
    valor_total = 0.0
    for alimento in alimentos_perros:
        valor_total += alimento['precio'] * alimento['cantidad']
    return valor_total

print(f"Valor total del inventario: {calcular_valor_inventario()} €")    

def realizar_compra():
    for cliente in clientes.values():
        carrito = []          # Lista de productos comprados en esta sesión
        total_compra = 0.0    # Total de la compra del cliente
        quiere_comprar = True
        maximo_intentos = 3
        intentos = 0
        print(f"\nHola, {cliente['nombre']}, ¡bienvenido! ¿Qué desea comprar?")

        while quiere_comprar and intentos < maximo_intentos:
            ver_inventario()
            nombre_producto = input("Ingrese el nombre del producto que desea comprar: ")
            print("llego aca")
            # Verificar si el producto existe en el inventario
            existe = any(alimento['nombre'].lower() == nombre_producto.lower() for alimento in alimentos_perros)
            if not existe:
                intentos += 1
                print(f"Producto '{nombre_producto}' no encontrado. Intento {intentos} de {maximo_intentos}.\n")
                continue  # Volver al inicio del bucle

            # Buscar el producto y solicitar cantidad
            for alimento in alimentos_perros:
                if alimento['nombre'].lower().strip() == nombre_producto.lower().strip():
                    cantidad_deseada = int(input(f"Ingrese la cantidad que desea comprar (Disponibles: {alimento['cantidad']}): "))

                    if cantidad_deseada > alimento['cantidad']:
                        print(f"No hay suficiente stock de {nombre_producto}. Stock disponible: {alimento['cantidad']}\n")
                    else:
                        # Agregar al carrito y actualizar inventario y total
                        carrito.append({
                            'nombre': nombre_producto,
                            'cantidad': cantidad_deseada,
                            'precio': alimento['precio']
                        })
                        total_compra = total_compra + alimento['precio'] * cantidad_deseada
                        alimento['cantidad'] = alimento['cantidad'] - cantidad_deseada
                    break

            # Preguntar si quiere seguir comprando
            seguir = input("¿Desea comprar otro producto? (si/no): ").strip().lower()
            if seguir != 'si':
                quiere_comprar = False

        # Guardar la compra en el historial del cliente
        if carrito:
            cliente['compra'].extend(carrito)
            print(f"\nCompra finalizada para {cliente['nombre']}. Total de la compra: {total_compra} €\n")
        else:
            print(f"{cliente['nombre']} no realizó ninguna compra.\n")
            
realizar_compra()
# Out:
# Nombre: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Stock actualizado para alimento para perro cachorro raza pequeña de 1kg. Nueva cantidad: 60
# El producto 'alimento para perro adulto raza pequeña' no se encontró en el inventario.
# Valor total del inventario: 1135.0 €
#
# Hola, Juan Perez, ¡bienvenido! ¿Qué desea comprar?
# Inventario actual:
# Articulo: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Articulo: alimento para perro cachorro raza pequeña de 1kg, Precio: 3 €, Cantidad: 165
# Articulo: perro pequeno, Precio: 55.0 €, Cantidad: 4
# Articulo: gata pequena , Precio: 5.1 €, Cantidad: 50
# llego aca
# Producto 'gata pequena' no encontrado. Intento 1 de 3.
#
# Inventario actual:
# Articulo: alimento para perro joven raza pequeña de 1kg, Precio: 3 €, Cantidad: 55
# Articulo: alimento para perro cachorro raza pequeña de 1kg, Precio: 3 €, Cantidad: 165
# Articulo: perro pequeno, Precio: 55.0 €, Cantidad: 4
# ...

# %%
class Producto : #renombre a producto porque es real y concreto tiene un nombre un precio y hay una cierta cantidad
    def __init__(self, articulo, precio, cantidad, edad, tamano): #metodo es init, es una funcion asociada a la clase y self hace referencia asi mismo
        
        
        #el atributo de la clase producto es que " es un ARTICULO que va a depender del tamaño y edad", " tiene un PRECIO" y " existe una cierta CANTIDAD"
        self.articulo = articulo    #iniciacion de atributos que sin variables asociadas a los objetos creados desde la clase
        self.precio = precio            #entonces son atributos de instancia
        self.cantidad = cantidad
       
    




perro_adulto_peq = Producto ("alimento para perro adulto raza pequeña de 1kg", 3, 50)  #instancia de la clase tienda
perro_adulto_mediana = Producto ("alimento para perro adulto raza mediana de 1kg", 4, 60)
perro_adulto_grande = Producto ("alimento pra perro adulto raza grande de 1kg", 4, 70)
perro_joven_peq = Producto ("alimento para perro joven raza pequeña de 1kg", 3, 55)
perro_joven_mediana = Producto("alimento para perro joven raza mediana de 1kg", 4, 65)
perro_joven_grande = Producto ("alimento para perro joven raza grande de 1kg", 4, 75)
perro_cachorro_peq = Producto ("alimento para perro cachorro raza pequeña de 1kg", 3, 45)
perro_cachorro_mediana = Producto ("alimento para perro cachorro raza mediana de 1kg", 3, 55)
perro_cachorro_grande = Producto ("alimento para perro cachorro raza grande de 1kg", 4, 65)  


# ESTA CLASE DEBO DEFINIR EL METODO porque esta es la ccion que puedo tener
# def listas_productos (self)

lista_productos= [perro_adulto_peq, perro_adulto_mediana, perro_adulto_grande,    #lista de producto de tienda
 perro_joven_peq,perro_joven_mediana, perro_joven_grande,
 perro_cachorro_peq, perro_cachorro_mediana, perro_cachorro_grande]
print(lista_productos) #no va porque vuelve a imprimir todo
for productos in lista_productos:   #bucle para recorrer los valores de (articulos, cantidad, precio) que estan en mi tienda para ver que funcione bien
    print ("Alimentos: ", productos.articulo)
    print ("Cantidad: ", productos.cantidad, "unidades")
    print ("Precio: ", productos.precio, "EUR" )
# Out:
# [<__main__.tienda object at 0x0000022E2A0E4440>, <__main__.tienda object at 0x0000022E29EDBED0>, <__main__.tienda object at 0x0000022E2A11C910>, <__main__.tienda object at 0x0000022E2A085220>, <__main__.tienda object at 0x0000022E2A087CE0>, <__main__.tienda object at 0x0000022E2A0B9A30>, <__main__.tienda object at 0x0000022E29F4A580>, <__main__.tienda object at 0x0000022E29F4A7A0>, <__main__.tienda object at 0x0000022E29EB3850>]
# Alimentos:  alimento para perro adulto raza pequeña de 1kg
# Cantidad:  50 unidades
# Precio:  3 EUR
# Alimentos:  alimento para perro adulto raza mediana de 1kg
# Cantidad:  60 unidades
# Precio:  4 EUR
# Alimentos:  alimento para perro adulto raza grande de 1kg
# Cantidad:  70 unidades
# Precio:  4 EUR
# Alimentos:  alimento para perro joven raza pequeña de 1kg
# Cantidad:  55 unidades
# Precio:  3 EUR
# Alimentos:  alimento para perro joven raza mediana de 1kg
# Cantidad:  65 unidades
# Precio:  4 EUR
# ...

# %% [markdown]
# # CLIENTES

# %%
class clientes: #
    def __init__(self, nombre_apellidos, email): #def es un metodo e init indica que es un metodo constructor donde self representa alas variables de la clase
        self.nombre_apellidos = nombre_apellidos # = operador que iguala la variable
        self.email = email
        self.compras =[] # lista vacia ´para guardar las compras
    def compras_realizadas( self, productos): #metodo dentro de la clase 
        self.compras.append(productos) #va agregando un producto al final
    def productos_comprados (self): # para poder llamar a los self de compra
        for productos in self.compras : # para poder ver los productos comprados del clientes es un bucle
             print ("Alimentos: ", productos.articulo)
             print ("Cantidad: ", productos.cantidad)
             print(f"Precio total de {productos.articulo}:  {productos.precio} eur") #insertar variable dentro del metodo de str cuando llamo a las variables usi {}
    def obtener_datos_clientes(self):
        print(self.nombre_apellidos)
        print(self.email)

edad = input("Hola el alimento que buscais es para un perro ¿adulto/joven/cachorro?")
tamano= input(" que tamaño es: ¿grande/mediana/pequeña? ")
cantidad1= int(input("cuanta cantidad os quiere"))

producto_articulo_nombre=""
producto_seleccionado = 0
for producto in lista_productos:
    if  (edad in producto.articulo  and tamano in producto.articulo): #condicional 
        producto_seleccionado= producto
        producto_articulo_nombre=producto.articulo
        break # para que no siga recorriendo si encontro una coincidencia el bucle for




nombre_apellidos= ["Mercedes Ramo", "Suzy Sanchez", "Juan Perez", "Rodrigo Potro"] 

email = ["meramo@gmail.com" , "suzychez@gmail.com", "juperez@gmail.com", "potro@gmail.com"]


cliente2 = clientes ( "Mercedes Ramo", "meramo@gmail.com")
cliente3 = clientes ("Suzy Sanchez", "suzychez@gmail.com" )
cliente4= clientes ("Juan Perez", "juperez@gmail.com")
cliente5= clientes ("Rodrigo Potro", "potro@gmail.com")
clientes_registrados = [ cliente2, cliente3, cliente4, cliente5]


compras_realizadas = 0

#cliente.compras_realizadas(tienda(edad + tamano, precio1, cantidad1))


#debo definir el tamaño y la edad en un self y ver si son preguntas categoricas o como integralos

for cliente in clientes_registrados: #para que recorra todos los clientes
    comprando = True 
    while comprando: #repite el bloque del codigo hasta q se cumpla la condicion
       
        edad = input("Hola el alimento que buscais es para un perro ¿adulto/joven/cachorro?").lower()
        tamano= input(" que tamaño es: ¿grande/mediana/pequeña? ").lower() #metodo todo minuscula si el cliente escribe en mayuscula algo
        cantidad1= int(input("cuanta cantidad os quiere")) # ingrese por teclado lo q desea el cliente e int es enteri
        producto_seleccionado = 0
        for producto in lista_productos:
            if  (edad in producto.articulo  and tamano in producto.articulo): #condicional and es el producto q busca el cliente
                producto_seleccionado= producto
                break # para que no siga recorriendo si encontro una coincidencia el bucle for
       
        cliente.compras_realizadas (tienda(edad + tamano, producto_seleccionado.precio*cantidad1, cantidad1))
        preguntas = input ("¿ quieres seguir comprando? responda si/no") 
        if (preguntas == "no"):
            comprando = False
            cliente.obtener_datos_clientes()
            cliente.productos_comprados()
ventas_totales = 0
for cliente in clientes_registrados: # para saber el total de ventas
    for compras_realizadas in cliente.compras:
        ventas_totales= ventas_totales + compras_realizadas.precio
print("la cantidad de ventas realizadas el dia de hoy fue: ", ventas_totales)
# Out:
# Mercedes Ramo
# meramo@gmail.com
# Alimentos:  jovenpequeña
# Cantidad:  5
# Precio total de jovenpequeña:  15 eur
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 57
#      55 edad = input("Hola el alimento que buscais es para un perro ¿adulto/joven/cachorro?").lower()
#      56 tamano= input(" que tamaño es: ¿grande/mediana/pequeña? ").lower() #metodo todo minuscula si el cliente escribe en mayuscula algo
# ---> 57 cantidad1= int(input("cuanta cantidad os quiere")) # ingrese por teclado lo q desea el cliente e int es enteri
#      58 producto_seleccionado = 0
#      59 for producto in lista_productos:
#
# ValueError: invalid literal for int() with base 10: ''
