# %% [markdown]
# TIENDA DE ALIMENTOS LULU

# %%
class tienda :
    def __init__(self, articulo, precio, cantidad):
        self.articulo = articulo    
        self.precio = precio
        self.cantidad = cantidad


articulo = {"alimento para perro adulto raza pequeña de 1kg", "alimento para perro adulto raza mediana de 1kg", "alimento para perro adulto raza grande  de1kg",
"alimento para perro joven raza pequeña de 1kg", "alimento para perro joven raza mediana de 1kg ", "alimento para perro joven raza grande de 1kg",
"alimento para perro cachorro raza pequeña de 1 kg", "alimento para perro cachorro raza mediana de 1 kg", "alimento para perro cachorro raza grande de 1kg"}
#precio = [ 3, 4, 4, 3, 4, 4, 3, 3, 4]
# ver donde esta el errror cantidad = {50, 60, 70, 55, 65, 75, 45,  55,  65 }  
perro_adulto_peq = tienda ("alimento para perro adulto raza pequeña de 1kg", 3, 50)
perro_adulto_mediana = tienda("alimento para perro adulto raza mediana de 1kg", 4, 60)
perro_adulto_grande = tienda("alimento para perro adulto raza grande de 1kg", 4, 70)
perro_joven_peq = tienda("alimento para perro joven raza pequeña de 1kg", 3, 55)
perro_joven_mediana = tienda("alimento para perro joven raza mediana de 1kg", 4, 65)
perro_joven_grande = tienda("alimento para perro joven raza grande de 1kg", 4, 75)
perro_cachorro_peq = tienda("alimento para perro cachorro raza pequeña de 1kg", 3, 45)
perro_cachorro_mediana = tienda("alimento para perro cachorro raza mediana de 1kg", 3, 55)
perro_cachorro_grande = tienda("alimento para perro cachorro raza grande de 1kg", 4, 65)  

lista_productos= [perro_adulto_peq, perro_adulto_mediana, perro_adulto_grande,
 perro_joven_peq,perro_joven_mediana, perro_joven_grande,
 perro_cachorro_peq, perro_cachorro_mediana, perro_cachorro_grande]
print(lista_productos)

for productos in lista_productos:
    print ("Alimentos: ", productos.articulo)
    print ("Cantidad: ", productos.cantidad, "unidades")
    print ("Precio: ", productos.precio, "EUR" )
# Out:
# [<__main__.tienda object at 0x0000015865C0EF90>, <__main__.tienda object at 0x0000015865881950>, <__main__.tienda object at 0x0000015865C9C7D0>, <__main__.tienda object at 0x0000015862BB5F30>, <__main__.tienda object at 0x0000015862BB6780>, <__main__.tienda object at 0x0000015865C796D0>, <__main__.tienda object at 0x00000158645139B0>, <__main__.tienda object at 0x0000015864513AC0>, <__main__.tienda object at 0x0000015865CC8850>]
# Alimentos:  alimento para perro adulto raza pequeña de 1kg
# Cantidad:  50 unidades
# Precio:  3 EUR
# Alimentos:  alimento para perro adulto raza mediana de 1kg
# Cantidad:  60 unidades
# Precio:  4 EUR
# Alimentos:  alimento para perro adulto raza grande de 1kg
# Cantidad:  70 unidades
# Precio:  4 EUR
# Alimentos:  alimento para perro joven raza pequeña de 1kg
# Cantidad:  55 unidades
# Precio:  3 EUR
# Alimentos:  alimento para perro joven raza mediana de 1kg
# Cantidad:  65 unidades
# Precio:  4 EUR
# ...

# %% [markdown]
# CLIENTES

# %%
class clientes:
    def __init__(self, nombre_apellidos, email):
        self.nombre_apellidos = nombre_apellidos
        self.email = email
        self.compras =[]
    def compras_realizadas( self, productos):
        self.compras.append(productos)
    def productos_comprados (self):
        for productos in self.compras :
             print ("Alimentos: ", productos.articulo)
             print ("Cantidad: ", productos.cantidad)
             print(f"Precio total de {productos.articulo}:  {productos.precio} eur") 
    def obtener_datos_clientes(self):
        print(self.nombre_apellidos)
        print(self.email)

edad = input("Hola el alimento que buscais es para un perro ¿adulto/joven/cachorro?")
tamano= input(" que tamaño es: ¿grande/mediana/pequeña? ")
cantidad1= int(input("cuanta cantidad os quiere"))

producto_articulo_nombre=""
producto_seleccionado = 0
for producto in lista_productos:
    if  (edad in producto.articulo  and tamano in producto.articulo):
        producto_seleccionado= producto
        producto_articulo_nombre=producto.articulo
        break




nombre_apellidos= ["Mercedes Ramo", "Suzy Sanchez", "Juan Perez", "Rodrigo Potro"]

email = ["meramo@gmail.com" , "suzychez@gmail.com", "juperez@gmail.com", "potro@gmail.com"]


cliente2 = clientes ( "Mercedes Ramo", "meramo@gmail.com")
cliente3 = clientes ("Suzy Sanchez", "suzychez@gmail.com" )
cliente4= clientes ("Juan Perez", "juperez@gmail.com")
cliente5= clientes ("Rodrigo Potro", "potro@gmail.com")
clientes_registrados = [ cliente2, cliente3, cliente4, cliente5]


compras_realizadas = 0

#cliente.compras_realizadas(tienda(edad + tamano, precio1, cantidad1))




for cliente in clientes_registrados:
    comprando = True 
    while comprando:
       
        edad = input("Hola el alimento que buscais es para un perro ¿adulto/joven/cachorro?").lower()
        tamano= input(" que tamaño es: ¿grande/mediana/pequeña? ").lower()
        cantidad1= int(input("cuanta cantidad os quiere"))
        producto_seleccionado = 0
        for producto in lista_productos:
            if  (edad in producto.articulo  and tamano in producto.articulo):
                producto_seleccionado= producto
                break
       
        cliente.compras_realizadas (tienda(edad + tamano, producto_seleccionado.precio*cantidad1, cantidad1))
        preguntas = input ("¿ quieres seguir comprando? responda si/no") 
        if (preguntas == "no"):
            comprando = False
            cliente.obtener_datos_clientes()
            cliente.productos_comprados()
ventas_totales = 0
for cliente in clientes_registrados:
    for compras_realizadas in cliente.compras:
        ventas_totales= ventas_totales + compras_realizadas.precio
print("la cantidad de ventas realizadas el dia de hoy fue: ", ventas_totales)
# Out:
# Mercedes Ramo
# meramo@gmail.com
# Alimentos:  adulto mediana
# Cantidad:  34
# Precio total de adulto mediana:  136 eur
# Suzy Sanchez
# suzychez@gmail.com
# Alimentos:  cachorropequeña
# Cantidad:  34
# Precio total de cachorropequeña:  102 eur
# Juan Perez
# juperez@gmail.com
# Alimentos:  jovengrande
# Cantidad:  3
# Precio total de jovengrande:  12 eur
# Rodrigo Potro
# potro@gmail.com
# Alimentos:  adultomediana
# Cantidad:  5
# Precio total de adultomediana:  20 eur
# la cantidad de ventas realizadas el dia de hoy fue:  270
